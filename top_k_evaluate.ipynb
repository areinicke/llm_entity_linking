# %% [markdown]
# ### Create data dictionary

# %%
import os
import json
import sys
import numpy as np

# %%
data = {}

# %% [markdown]
# #### Identify relevant runs

# %%
datasets = {"AIDA",
            "cweb",
            "reddit-comments",
            "reddit-posts",
            "shadowlinks-shadow",
            "shadowlinks-tail",
            "shadowlinks-top",
            "tweeki",
            "wned-wiki"}

results_folder_path = "Google/gemini-2.5-flash-lite"
req_dates = ["2025-10-30"]
run_criteria = {"top_k": 20}
split = "test"

# %%
def parse_line(line):
    try:
        gold = line.split("---")[0].split("/")[1].strip()
        de_pred = line.split("---")[1].strip()
        llm_pred = line.split("---")[2].strip()

        if llm_pred == "N/A":
            return None, None, None, None

        preds = []
        preds_str = line.split("---")[3].strip()[2:-2]  # Remove leading "[(" and trailing ")]"
        for pred_str in preds_str.split("), ("):
            preds.append((pred_str.split(", ")[0][1:-1].strip(), float(pred_str.split(", ")[1].strip())))

        return gold, de_pred, llm_pred, preds
    except:
        return None, None, None, None

# %%
def read_run_predictions(data, dataset, results_folder_path, subfolder, split):
    file_path = os.path.join("Results", dataset, results_folder_path, subfolder, f"predictions_{split}.txt")
    if not os.path.exists(file_path):
        print(f"File not found: {file_path}")
        return

    # Read File line by line
    with open(file_path, 'r') as f:
        data[dataset][subfolder] = {}
        for line in f:
            if not line.startswith('"'):
                continue
            # Parse the line
            gold, de_pred, llm_pred, preds = parse_line(line)

            if gold is None:    # Happens when there was an error parsing the line or the LLM did not make a prediction
                continue
            
            # Get the score (rounded to nearest integer) of the top prediction
            score = int(round(preds[0][1], 0))
            if not score in data[dataset][subfolder]:
                # Total: Number of spans that have this score
                # correct_llm: Number of spans with this score where LLM prediction is correct
                # correct_de: Number of spans with this score where DE prediction is correct
                # gold_in_preds: Number of spans with this score where gold entity is in predictions
                # gold_pred_ranks: List of ranks at which gold entity was found in predictions. Spans where gold entity was not found are not included.
                data[dataset][subfolder][score] = {"total": 0,
                                                   "correct_llm": 0,
                                                   "correct_de": 0,
                                                   "gold_in_preds": 0,
                                                   "gold_pred_ranks": [],
                                                   "gold_top_1_diff_abs": [],
                                                   "gold_top_1_diff_perc": []}

            # Update the counts
            data[dataset][subfolder][score]["total"] += 1
            if llm_pred == gold:
                data[dataset][subfolder][score]["correct_llm"] += 1
            if de_pred == gold:
                data[dataset][subfolder][score]["correct_de"] += 1
            
            # See if gold in preds and get rank
            for i, (pred, pred_score) in enumerate(preds):
                if pred == gold:
                    data[dataset][subfolder][score]["gold_pred_ranks"].append(i + 1)
                    data[dataset][subfolder][score]["gold_in_preds"] += 1
                    data[dataset][subfolder][score]["gold_top_1_diff_abs"].append(abs(pred_score - score))
                    data[dataset][subfolder][score]["gold_top_1_diff_perc"].append((pred_score - score) / score * 100 if score != 0 else 0)
                    break
    
    for score in data[dataset][subfolder]:
        data[dataset][subfolder][score]["gold_preds_rank_avg"] = float(round(np.mean(data[dataset][subfolder][score]["gold_pred_ranks"]) if data[dataset][subfolder][score]["gold_pred_ranks"] else 0.0, 2))
        data[dataset][subfolder][score]["gold_preds_rank_75th"] = float(round(np.percentile(data[dataset][subfolder][score]["gold_pred_ranks"], 90) if data[dataset][subfolder][score]["gold_pred_ranks"] else 0.0, 2))
    
        data[dataset][subfolder][score]["gold_top_1_diff_abs_avg"] = float(round(np.mean(data[dataset][subfolder][score]["gold_top_1_diff_abs"]) if data[dataset][subfolder][score]["gold_top_1_diff_abs"] else 0.0, 2))
        data[dataset][subfolder][score]["gold_top_1_diff_perc_avg"] = float(round(np.mean(data[dataset][subfolder][score]["gold_top_1_diff_perc"]) if data[dataset][subfolder][score]["gold_top_1_diff_perc"] else 0.0, 2))
    # Sort the dictionary by score
    data[dataset][subfolder] = dict(sorted(data[dataset][subfolder].items()))

# %%
for dataset in datasets:
    if not dataset in data:
        data[dataset] = {}

    # Get names of all Subfolders in dataset folder (Results/<dataset>/<results_folder_path>/)
    subfolders = [f.name for f in os.scandir(f"Results/{dataset}/{results_folder_path}/") if f.is_dir()]
    
    for subfolder in subfolders:
        # Check if subfolder timestamp contains a valid date
        valid = False
        for req_date in req_dates:
            if req_date in subfolder:
                valid = True
                break
        if not valid:
            continue

        # Check if run meets criteria
        run_args = json.load(open(f"Results/{dataset}/{results_folder_path}/{subfolder}/run_parameters.json", "r"))

        valid = True
        for key, value in run_criteria.items():
            if key not in run_args or run_args[key] != value:
                valid = False
                break

        if not valid:
            continue

        # Read Run results
        read_run_predictions(data, dataset, results_folder_path, subfolder, split)


print("Printing statistics")
for i in range(-30, 0, 1):
    print(f"Score: {i}")
    global_avgs = []
    global_75ths = []
    global_gold_top_1_diff_abs_list = []
    global_gold_top_1_diff_perc_list = []
    for dataset in data:
        _avg_rank_list = []
        _75th_rank_list = []
        _gold_top_1_diff_abs_list = []
        _gold_top_1_diff_perc_list = []
        for subfolder in data[dataset]:
            if i in data[dataset][subfolder]:
                _avg_rank_list.append(data[dataset][subfolder][i]["gold_preds_rank_avg"])
                _75th_rank_list.append(data[dataset][subfolder][i]["gold_preds_rank_75th"])
                _gold_top_1_diff_abs_list.append(data[dataset][subfolder][i]["gold_top_1_diff_abs_avg"])
                _gold_top_1_diff_perc_list.append(data[dataset][subfolder][i]["gold_top_1_diff_perc_avg"])
        if len(_avg_rank_list) > 0:
            avg_rank = float(round(np.mean(_avg_rank_list), 2))
            global_avgs.append(avg_rank)
            rank_75th = float(round(np.mean(_75th_rank_list), 2))
            global_75ths.append(rank_75th)
            print(f"{dataset}: Avg Rank: {avg_rank}, 75th Percentile Rank: {rank_75th}")
        
        if len(_gold_top_1_diff_abs_list) > 0:
            gold_top_1_diff_abs = float(round(np.mean(_gold_top_1_diff_abs_list), 2))
            global_gold_top_1_diff_abs_list.append(gold_top_1_diff_abs)
            gold_top_1_diff_rel = float(round(np.mean(_gold_top_1_diff_perc_list), 2))
            global_gold_top_1_diff_perc_list.append(gold_top_1_diff_rel)
            print(f"-      Avg Gold Top-1 Diff Abs: {gold_top_1_diff_abs}, Avg Gold Top-1 Diff Perc: {gold_top_1_diff_rel}")

    if len(global_avgs) > 0:
        print()
        print(f"Avg Global Avg Rank: {float(round(np.mean(global_avgs), 2))}, 75th: {float(round(np.percentile(global_avgs, 75), 2))}, Last: {float(round(np.max(global_avgs), 2))}")
        print(f"Avg Global 75th% Rank: {float(round(np.mean(global_75ths), 2))}, 75th: {float(round(np.percentile(global_75ths, 75), 2))}, Last: {float(round(np.max(global_75ths), 2))}")

    if len(global_gold_top_1_diff_abs_list) > 0:
        print(f"Avg Global Gold Top-1 Diff Abs: {float(round(np.mean(global_gold_top_1_diff_abs_list), 2))}, 75th: {float(round(np.percentile(global_gold_top_1_diff_abs_list, 75), 2))}, Last: {float(round(np.max(global_gold_top_1_diff_abs_list), 2))}")

    if len(global_gold_top_1_diff_perc_list) > 0:
        print(f"Avg Global Gold Top-1 Diff Perc: {float(round(np.mean(global_gold_top_1_diff_perc_list), 2))}, 75th: {float(round(np.percentile(global_gold_top_1_diff_perc_list, 75), 2))}, Last: {float(round(np.max(global_gold_top_1_diff_perc_list), 2))}")

    print()
    print("--------------------------------------------------")
    print()
# Out:
# Printing statistics
# Score: -30
#
# --------------------------------------------------
#
# Score: -29
#
# --------------------------------------------------
#
# Score: -28
# shadowlinks-top: Avg Rank: 4.0, 75th Percentile Rank: 4.0
# -      Avg Gold Top-1 Diff Abs: 0.15, Avg Gold Top-1 Diff Perc: -0.54
# tweeki: Avg Rank: 6.0, 75th Percentile Rank: 13.0
# -      Avg Gold Top-1 Diff Abs: 0.55, Avg Gold Top-1 Diff Perc: 0.8
# reddit-comments: Avg Rank: 9.0, 75th Percentile Rank: 13.8
# -      Avg Gold Top-1 Diff Abs: 0.58, Avg Gold Top-1 Diff Perc: 1.13
# wned-wiki: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.31, Avg Gold Top-1 Diff Perc: -1.12
# cweb: Avg Rank: 7.0, 75th Percentile Rank: 7.8
# -      Avg Gold Top-1 Diff Abs: 0.3, Avg Gold Top-1 Diff Perc: 1.06
#
# Avg Global Avg Rank: 5.4, 75th: 7.0, Last: 9.0
# Avg Global 75th% Rank: 7.92, 75th: 13.0, Last: 13.8
# Avg Global Gold Top-1 Diff Abs: 0.38, 75th: 0.55, Last: 0.58
# Avg Global Gold Top-1 Diff Perc: 0.27, 75th: 1.06, Last: 1.13
#
# --------------------------------------------------
#
# Score: -27
# shadowlinks-shadow: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.31, Avg Gold Top-1 Diff Perc: -1.14
# shadowlinks-top: Avg Rank: 4.83, 75th Percentile Rank: 10.5
# -      Avg Gold Top-1 Diff Abs: 0.51, Avg Gold Top-1 Diff Perc: 0.63
# tweeki: Avg Rank: 2.56, 75th Percentile Rank: 4.2
# -      Avg Gold Top-1 Diff Abs: 0.33, Avg Gold Top-1 Diff Perc: 0.35
# AIDA: Avg Rank: 7.67, 75th Percentile Rank: 15.2
# -      Avg Gold Top-1 Diff Abs: 0.3, Avg Gold Top-1 Diff Perc: 0.08
# shadowlinks-tail: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.08, Avg Gold Top-1 Diff Perc: -0.29
# reddit-comments: Avg Rank: 4.0, 75th Percentile Rank: 4.8
# -      Avg Gold Top-1 Diff Abs: 0.4, Avg Gold Top-1 Diff Perc: 1.47
# wned-wiki: Avg Rank: 5.8, 75th Percentile Rank: 12.2
# -      Avg Gold Top-1 Diff Abs: 0.32, Avg Gold Top-1 Diff Perc: 0.68
# cweb: Avg Rank: 4.94, 75th Percentile Rank: 9.0
# -      Avg Gold Top-1 Diff Abs: 0.39, Avg Gold Top-1 Diff Perc: 0.88
# reddit-posts: Avg Rank: 1.25, 75th Percentile Rank: 1.7
# -      Avg Gold Top-1 Diff Abs: 0.36, Avg Gold Top-1 Diff Perc: -1.33
#
# Avg Global Avg Rank: 3.67, 75th: 4.94, Last: 7.67
# Avg Global 75th% Rank: 6.62, 75th: 10.5, Last: 15.2
# Avg Global Gold Top-1 Diff Abs: 0.33, 75th: 0.39, Last: 0.51
# Avg Global Gold Top-1 Diff Perc: 0.15, 75th: 0.68, Last: 1.47
#
# --------------------------------------------------
#
# Score: -26
# shadowlinks-shadow: Avg Rank: 3.33, 75th Percentile Rank: 6.0
# -      Avg Gold Top-1 Diff Abs: 0.52, Avg Gold Top-1 Diff Perc: 1.05
# shadowlinks-top: Avg Rank: 3.0, 75th Percentile Rank: 6.0
# -      Avg Gold Top-1 Diff Abs: 0.42, Avg Gold Top-1 Diff Perc: 0.66
# tweeki: Avg Rank: 3.1, 75th Percentile Rank: 9.1
# -      Avg Gold Top-1 Diff Abs: 0.44, Avg Gold Top-1 Diff Perc: 1.38
# AIDA: Avg Rank: 6.17, 75th Percentile Rank: 13.0
# -      Avg Gold Top-1 Diff Abs: 0.44, Avg Gold Top-1 Diff Perc: 1.29
# shadowlinks-tail: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.05, Avg Gold Top-1 Diff Perc: -0.19
# reddit-comments: Avg Rank: 2.44, 75th Percentile Rank: 4.2
# -      Avg Gold Top-1 Diff Abs: 0.38, Avg Gold Top-1 Diff Perc: 0.81
# wned-wiki: Avg Rank: 3.24, 75th Percentile Rank: 8.0
# -      Avg Gold Top-1 Diff Abs: 0.29, Avg Gold Top-1 Diff Perc: 0.27
# cweb: Avg Rank: 4.96, 75th Percentile Rank: 13.7
# -      Avg Gold Top-1 Diff Abs: 0.49, Avg Gold Top-1 Diff Perc: 1.25
# reddit-posts: Avg Rank: 1.89, 75th Percentile Rank: 3.6
# -      Avg Gold Top-1 Diff Abs: 0.4, Avg Gold Top-1 Diff Perc: 0.09
#
# Avg Global Avg Rank: 3.24, 75th: 3.33, Last: 6.17
# Avg Global 75th% Rank: 7.18, 75th: 9.1, Last: 13.7
# Avg Global Gold Top-1 Diff Abs: 0.38, 75th: 0.44, Last: 0.52
# Avg Global Gold Top-1 Diff Perc: 0.73, 75th: 1.25, Last: 1.38
#
# --------------------------------------------------
#
# Score: -25
# shadowlinks-shadow: Avg Rank: 3.7, 75th Percentile Rank: 9.0
# -      Avg Gold Top-1 Diff Abs: 0.71, Avg Gold Top-1 Diff Perc: 2.35
# shadowlinks-top: Avg Rank: 2.91, 75th Percentile Rank: 7.0
# -      Avg Gold Top-1 Diff Abs: 0.55, Avg Gold Top-1 Diff Perc: 1.34
# tweeki: Avg Rank: 3.13, 75th Percentile Rank: 10.0
# -      Avg Gold Top-1 Diff Abs: 0.56, Avg Gold Top-1 Diff Perc: 1.39
# AIDA: Avg Rank: 2.43, 75th Percentile Rank: 5.4
# -      Avg Gold Top-1 Diff Abs: 0.42, Avg Gold Top-1 Diff Perc: 0.75
# shadowlinks-tail: Avg Rank: 1.17, 75th Percentile Rank: 1.5
# -      Avg Gold Top-1 Diff Abs: 0.3, Avg Gold Top-1 Diff Perc: 0.32
# reddit-comments: Avg Rank: 2.17, 75th Percentile Rank: 4.0
# -      Avg Gold Top-1 Diff Abs: 0.36, Avg Gold Top-1 Diff Perc: 0.63
# wned-wiki: Avg Rank: 3.21, 75th Percentile Rank: 8.4
# -      Avg Gold Top-1 Diff Abs: 0.47, Avg Gold Top-1 Diff Perc: 0.94
# cweb: Avg Rank: 3.79, 75th Percentile Rank: 9.0
# -      Avg Gold Top-1 Diff Abs: 0.56, Avg Gold Top-1 Diff Perc: 1.67
# reddit-posts: Avg Rank: 2.13, 75th Percentile Rank: 4.8
# -      Avg Gold Top-1 Diff Abs: 0.34, Avg Gold Top-1 Diff Perc: 0.7
#
# Avg Global Avg Rank: 2.74, 75th: 3.21, Last: 3.79
# Avg Global 75th% Rank: 6.57, 75th: 9.0, Last: 10.0
# Avg Global Gold Top-1 Diff Abs: 0.47, 75th: 0.56, Last: 0.71
# Avg Global Gold Top-1 Diff Perc: 1.12, 75th: 1.39, Last: 2.35
#
# --------------------------------------------------
#
# Score: -24
# shadowlinks-shadow: Avg Rank: 2.51, 75th Percentile Rank: 6.8
# -      Avg Gold Top-1 Diff Abs: 0.57, Avg Gold Top-1 Diff Perc: 1.57
# shadowlinks-top: Avg Rank: 2.88, 75th Percentile Rank: 6.9
# -      Avg Gold Top-1 Diff Abs: 0.78, Avg Gold Top-1 Diff Perc: 2.91
# tweeki: Avg Rank: 2.67, 75th Percentile Rank: 5.5
# -      Avg Gold Top-1 Diff Abs: 0.53, Avg Gold Top-1 Diff Perc: 1.8
# AIDA: Avg Rank: 2.55, 75th Percentile Rank: 5.6
# -      Avg Gold Top-1 Diff Abs: 0.45, Avg Gold Top-1 Diff Perc: 1.04
# shadowlinks-tail: Avg Rank: 1.5, 75th Percentile Rank: 2.2
# -      Avg Gold Top-1 Diff Abs: 0.3, Avg Gold Top-1 Diff Perc: 0.04
# reddit-comments: Avg Rank: 3.02, 75th Percentile Rank: 10.2
# -      Avg Gold Top-1 Diff Abs: 0.61, Avg Gold Top-1 Diff Perc: 2.0
# wned-wiki: Avg Rank: 2.66, 75th Percentile Rank: 6.7
# -      Avg Gold Top-1 Diff Abs: 0.56, Avg Gold Top-1 Diff Perc: 1.57
# cweb: Avg Rank: 3.18, 75th Percentile Rank: 9.0
# -      Avg Gold Top-1 Diff Abs: 0.64, Avg Gold Top-1 Diff Perc: 2.19
# reddit-posts: Avg Rank: 1.44, 75th Percentile Rank: 2.4
# -      Avg Gold Top-1 Diff Abs: 0.35, Avg Gold Top-1 Diff Perc: 0.62
#
# Avg Global Avg Rank: 2.49, 75th: 2.88, Last: 3.18
# Avg Global 75th% Rank: 6.14, 75th: 6.9, Last: 10.2
# Avg Global Gold Top-1 Diff Abs: 0.53, 75th: 0.61, Last: 0.78
# Avg Global Gold Top-1 Diff Perc: 1.53, 75th: 2.0, Last: 2.91
#
# --------------------------------------------------
#
# Score: -23
# shadowlinks-shadow: Avg Rank: 1.94, 75th Percentile Rank: 4.0
# -      Avg Gold Top-1 Diff Abs: 0.83, Avg Gold Top-1 Diff Perc: 3.38
# shadowlinks-top: Avg Rank: 1.54, 75th Percentile Rank: 3.4
# -      Avg Gold Top-1 Diff Abs: 0.4, Avg Gold Top-1 Diff Perc: 1.02
# tweeki: Avg Rank: 1.37, 75th Percentile Rank: 2.2
# -      Avg Gold Top-1 Diff Abs: 0.55, Avg Gold Top-1 Diff Perc: 1.92
# AIDA: Avg Rank: 2.07, 75th Percentile Rank: 4.0
# -      Avg Gold Top-1 Diff Abs: 0.53, Avg Gold Top-1 Diff Perc: 1.58
# shadowlinks-tail: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.29, Avg Gold Top-1 Diff Perc: -0.79
# reddit-comments: Avg Rank: 1.71, 75th Percentile Rank: 2.0
# -      Avg Gold Top-1 Diff Abs: 0.43, Avg Gold Top-1 Diff Perc: 0.97
# wned-wiki: Avg Rank: 2.34, 75th Percentile Rank: 5.4
# -      Avg Gold Top-1 Diff Abs: 0.54, Avg Gold Top-1 Diff Perc: 1.66
# cweb: Avg Rank: 1.48, 75th Percentile Rank: 3.0
# -      Avg Gold Top-1 Diff Abs: 0.76, Avg Gold Top-1 Diff Perc: 3.32
# reddit-posts: Avg Rank: 1.52, 75th Percentile Rank: 2.1
# -      Avg Gold Top-1 Diff Abs: 0.37, Avg Gold Top-1 Diff Perc: 0.59
#
# Avg Global Avg Rank: 1.66, 75th: 1.94, Last: 2.34
# Avg Global 75th% Rank: 3.01, 75th: 4.0, Last: 5.4
# Avg Global Gold Top-1 Diff Abs: 0.52, 75th: 0.55, Last: 0.83
# Avg Global Gold Top-1 Diff Perc: 1.52, 75th: 1.92, Last: 3.38
#
# --------------------------------------------------
#
# Score: -22
# shadowlinks-shadow: Avg Rank: 2.25, 75th Percentile Rank: 4.9
# -      Avg Gold Top-1 Diff Abs: 0.61, Avg Gold Top-1 Diff Perc: 2.48
# shadowlinks-top: Avg Rank: 2.43, 75th Percentile Rank: 4.4
# -      Avg Gold Top-1 Diff Abs: 0.79, Avg Gold Top-1 Diff Perc: 3.38
# tweeki: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.38, Avg Gold Top-1 Diff Perc: 1.71
# AIDA: Avg Rank: 1.82, 75th Percentile Rank: 4.0
# -      Avg Gold Top-1 Diff Abs: 0.6, Avg Gold Top-1 Diff Perc: 2.61
# shadowlinks-tail: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.2, Avg Gold Top-1 Diff Perc: 0.34
# reddit-comments: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.38, Avg Gold Top-1 Diff Perc: 0.73
# wned-wiki: Avg Rank: 1.89, 75th Percentile Rank: 3.0
# -      Avg Gold Top-1 Diff Abs: 0.54, Avg Gold Top-1 Diff Perc: 1.58
# reddit-posts: Avg Rank: 1.62, 75th Percentile Rank: 2.5
# -      Avg Gold Top-1 Diff Abs: 0.49, Avg Gold Top-1 Diff Perc: 2.04
#
# Avg Global Avg Rank: 1.63, 75th: 1.98, Last: 2.43
# Avg Global 75th% Rank: 2.72, 75th: 4.1, Last: 4.9
# Avg Global Gold Top-1 Diff Abs: 0.5, 75th: 0.6, Last: 0.79
# Avg Global Gold Top-1 Diff Perc: 1.86, 75th: 2.51, Last: 3.38
#
# --------------------------------------------------
#
# Score: -21
# AIDA: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.43, Avg Gold Top-1 Diff Perc: 2.04
# shadowlinks-tail: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.24, Avg Gold Top-1 Diff Perc: -0.09
# wned-wiki: Avg Rank: 1.42, 75th Percentile Rank: 2.0
# -      Avg Gold Top-1 Diff Abs: 0.4, Avg Gold Top-1 Diff Perc: 0.87
# reddit-posts: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.32, Avg Gold Top-1 Diff Perc: 1.05
#
# Avg Global Avg Rank: 1.1, 75th: 1.1, Last: 1.42
# Avg Global 75th% Rank: 1.25, 75th: 1.25, Last: 2.0
# Avg Global Gold Top-1 Diff Abs: 0.35, 75th: 0.41, Last: 0.43
# Avg Global Gold Top-1 Diff Perc: 0.97, 75th: 1.3, Last: 2.04
#
# --------------------------------------------------
#
# Score: -20
# shadowlinks-tail: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.29, Avg Gold Top-1 Diff Perc: 0.11
# wned-wiki: Avg Rank: 1.41, 75th Percentile Rank: 2.0
# -      Avg Gold Top-1 Diff Abs: 0.45, Avg Gold Top-1 Diff Perc: 1.4
#
# Avg Global Avg Rank: 1.2, 75th: 1.31, Last: 1.41
# Avg Global 75th% Rank: 1.5, 75th: 1.75, Last: 2.0
# Avg Global Gold Top-1 Diff Abs: 0.37, 75th: 0.41, Last: 0.45
# Avg Global Gold Top-1 Diff Perc: 0.76, 75th: 1.08, Last: 1.4
#
# --------------------------------------------------
#
# Score: -19
# shadowlinks-tail: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.27, Avg Gold Top-1 Diff Perc: 0.03
# wned-wiki: Avg Rank: 1.12, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.5, Avg Gold Top-1 Diff Perc: 2.64
#
# Avg Global Avg Rank: 1.06, 75th: 1.09, Last: 1.12
# Avg Global 75th% Rank: 1.0, 75th: 1.0, Last: 1.0
# Avg Global Gold Top-1 Diff Abs: 0.38, 75th: 0.44, Last: 0.5
# Avg Global Gold Top-1 Diff Perc: 1.34, 75th: 1.99, Last: 2.64
#
# --------------------------------------------------
#
# Score: -18
# shadowlinks-tail: Avg Rank: 1.0, 75th Percentile Rank: 1.0
# -      Avg Gold Top-1 Diff Abs: 0.23, Avg Gold Top-1 Diff Perc: 0.72
#
# Avg Global Avg Rank: 1.0, 75th: 1.0, Last: 1.0
# Avg Global 75th% Rank: 1.0, 75th: 1.0, Last: 1.0
# Avg Global Gold Top-1 Diff Abs: 0.23, 75th: 0.23, Last: 0.23
# Avg Global Gold Top-1 Diff Perc: 0.72, 75th: 0.72, Last: 0.72
#
# --------------------------------------------------
#
# Score: -17
#
# --------------------------------------------------
#
# Score: -16
#
# --------------------------------------------------
#
# Score: -15
#
# --------------------------------------------------
#
# Score: -14
#
# --------------------------------------------------
#
# Score: -13
#
# --------------------------------------------------
#
# Score: -12
#
# --------------------------------------------------
#
# Score: -11
#
# --------------------------------------------------
#
# Score: -10
#
# --------------------------------------------------
#
# Score: -9
#
# --------------------------------------------------
#
# Score: -8
#
# --------------------------------------------------
#
# Score: -7
#
# --------------------------------------------------
#
# Score: -6
#
# --------------------------------------------------
#
# Score: -5
#
# --------------------------------------------------
#
# Score: -4
#
# --------------------------------------------------
#
# Score: -3
#
# --------------------------------------------------
#
# Score: -2
#
# --------------------------------------------------
#
# Score: -1
#
# --------------------------------------------------

# %% [markdown]
# ### Generate graphics
