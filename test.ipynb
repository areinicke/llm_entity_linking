# %%
import pickle

with open("sentence_cache/AIDA/sentences_2_predictions_test.pkl", "rb") as f:
    sentence_dict = pickle.load(f)
    loss = pickle.load(f)

# %%
sentence_dict
# Out:
# {0: {0: {'text': 'FRENCH',
#    'start_position': 9,
#    'end_position': 15,
#    'predicted': ('Football_in_France', -21.840595245361328),
#    'top_0': ('Football_in_France', -21.840595245361328),
#    'top_1': ('French_Football_Federation', -22.741302490234375),
#    'top_2': ('Ligue_2', -23.16565704345703),
#    'top_3': ('French_football_league_system', -23.20379638671875),
#    'top_4': ('France_Football', -23.43963623046875),
#    'top_5': ('Sport_in_France', -23.55838966369629),
#    'top_6': ('Ligue_1', -23.56229591369629),
#    'top_7': ('Coupe_de_France', -23.6496524810791),
#    'top_8': ('France', -23.765596389770508),
#    'top_9': ('Coupe_de_la_Ligue', -24.17702865600586),
#    'top_10': ('National_Rugby_League_(France)', -24.189794540405273),
#    'top_11': ('Ligue_de_Football_Professionnel', -24.345706939697266),
#    'top_12': ('Rugby_league_in_France', -24.613544464111328),
#    'top_13': ('Division_1_Féminine', -24.806467056274414),
# ...
